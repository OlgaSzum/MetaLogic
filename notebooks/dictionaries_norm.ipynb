# %%
"""
Próba normalizacji słowników (bez zapisu do oryginalnych plików):
- importuje src/dictionaries.py
- wczytuje oba CSV
- pokazuje podgląd i podstawowe statystyki
- (opcjonalnie) zapisuje tylko pliki _TEST_*.csv
"""

from pathlib import Path
import pandas as pd

from src.dictionaries import DictSpec, load_dictionary

DICT_SUBJ = Path("/Users/olga/MetaLogic/data/dictionary_subjects.csv")
DICT_SCEN = Path("/Users/olga/MetaLogic/data/dictionary_scenes.csv")

df_subj = load_dictionary(DictSpec(DICT_SUBJ, "subjects"))
df_scen = load_dictionary(DictSpec(DICT_SCEN, "scenes"))

display(df_subj.head(30))
display(df_scen.head(30))

print("SUBJECTS:", len(df_subj), "rows | brak PL:", int((df_subj["pl"].astype(str).str.strip() == "").sum()))
print("SCENES:  ", len(df_scen), "rows | brak PL:", int((df_scen["pl"].astype(str).str.strip() == "").sum()))

print("SUBJECTS duplicate keys:", int(df_subj["key"].duplicated().sum()))
print("SCENES duplicate keys:  ", int(df_scen["key"].duplicated().sum()))

display(df_subj.loc[df_subj["pl"].astype(str).str.strip() == "", ["key", "en", "pl"]].head(30))
display(df_scen.loc[df_scen["pl"].astype(str).str.strip() == "", ["key", "en", "pl"]].head(30))

# OPCJONALNIE: zapis próbny (nie nadpisuje oryginałów)
OUT_SUBJ = Path("/Users/olga/MetaLogic/data/_TEST_dictionary_subjects.normalized.csv")
OUT_SCEN = Path("/Users/olga/MetaLogic/data/_TEST_dictionary_scenes.normalized.csv")

df_subj.to_csv(OUT_SUBJ, index=False)
df_scen.to_csv(OUT_SCEN, index=False)

print("Wrote test files:")
print(" -", OUT_SUBJ)
print(" -", OUT_SCEN)
# Out:
#                        en                     pl notes  active updated_at  \
# 0             aerosol_can      puszka aerozolowa          True
# 1         air_conditioner           klimatyzator          True
# 2                airplane                samolot          True
# 3             alarm_clock                 budzik          True
# 4                 alcohol                alkohol          True
# 5               alligator               aligator          True
# 6                  almond                 migdał          True
# 7               ambulance                karetka          True
# 8               amplifier             wzmacniacz          True
# 9                  anklet  bransoletka na kostkę          True
# 10                antenna                 antena          True
# 11                  apple                 jabłko          True
# 12             applesauce           mus jabłkowy          True
# 13                apricot                 morela          True
# 14                  apron                fartuch          True
# 15               aquarium               akwarium          True
# 16  arctic_(type_of_shoe)           but śniegowy          True
# 17                armband        opaska na ramię          True
# 18               armchair                  fotel          True
# 19                armoire                  szafa          True
# 20                  armor                 zbroja          True
# 21              army_tank                  czołg          True
# 22              artichoke               karczoch          True
# 23                ashtray           popielniczka          True
# 24              asparagus               szparagi          True
# 25               atomizer               atomizer          True
# 26       automatic_washer    pralka automatyczna          True
# 27                avocado                awokado          True
# 28                  award                nagroda          True
# 29                 awning                markiza          True
#
#                     key      kind
# 0           aerosol_can  subjects
# 1       air_conditioner  subjects
# 2              airplane  subjects
# 3           alarm_clock  subjects
# 4               alcohol  subjects
# 5             alligator  subjects
# 6                almond  subjects
# 7             ambulance  subjects
# 8             amplifier  subjects
# 9                anklet  subjects
# 10              antenna  subjects
# 11                apple  subjects
# 12           applesauce  subjects
# 13              apricot  subjects
# 14                apron  subjects
# 15             aquarium  subjects
# 16  arctic_type_of_shoe  subjects
# 17              armband  subjects
# 18             armchair  subjects
# 19              armoire  subjects
# 20                armor  subjects
# 21            army_tank  subjects
# 22            artichoke  subjects
# 23              ashtray  subjects
# 24            asparagus  subjects
# 25             atomizer  subjects
# 26     automatic_washer  subjects
# 27              avocado  subjects
# 28                award  subjects
# 29               awning  subjects
#                                             en  \
# 0                            airplane exterior
# 1                     airport or train station
# 2                         apartment block area
# 3                      bicycles or motorcycles
# 4                          bridges or viaducts
# 5                         bus or tram exterior
# 6                                 car exterior
# 7                 cigarettes or street smoking
# 8                                    city park
# 9                                  city square
# 10                        cloudy weather scene
# 11                           construction site
# 12                                country road
# 13          crowd of people at an indoor event
# 14               crowd of people on the street
# 15                            factory exterior
# 16                            factory interior
# 17                          farmland landscape
# 18           fountains or urban water features
# 19      graffiti or political slogans on walls
# 20                     group of people indoors
# 21                    group of people outdoors
# 22             historic buildings or tenements
# 23                    hot air balloon exterior
# 24                          interior of a flat
# 25                         lake or river scene
# 26             modern buildings or skyscrapers
# 27               monuments or urban sculptures
# 28                       music studio interior
# 29  musical instruments or street performances
#
#                                           pl notes  active updated_at  \
# 0                                    samolot          True
# 1                       lotnisko lub dworzec          True
# 2        blokowisko lub osiedle mieszkaniowe          True
# 3                       rowery lub motocykle          True
# 4                         mosty lub wiadukty          True
# 5                        autobus lub tramwaj          True
# 6                                       auto          True
# 7             papierosy lub palenie na ulicy          True
# 8                    park lub zieleń miejska          True
# 9                               plac miejski          True
# 10                          pochmurna pogoda          True
# 11                               plac budowy          True
# 12                             droga wiejska          True
# 13               tłum na wydarzeniu wewnątrz          True
# 14                             tłum na ulicy          True
# 15            fabryka lub zakład przemysłowy          True
# 16                     wnętrze zakładu pracy          True
# 17                       pola i gospodarstwa          True
# 18     fontanny lub miejskie zbiorniki wodne          True
# 19                napisy lub hasła na murach          True
# 20               grupa ludzi w pomieszczeniu          True
# 21                   grupa ludzi na zewnątrz          True
# 22           kamienice lub zabytkowe budynki          True
# 23                                     balon          True
# 24                        wnętrze mieszkania          True
# 25                         jezioro lub rzeka          True
# 26           nowoczesne budynki lub wieżowce          True
# 27               pomniki lub rzeźby miejskie          True
# 28                           studio muzyczne          True
# 29  instrumenty muzyczne lub występy uliczne          True
#
#                                            key    kind
# 0                            airplane_exterior  scenes
# 1                     airport_or_train_station  scenes
# 2                         apartment_block_area  scenes
# 3                      bicycles_or_motorcycles  scenes
# 4                          bridges_or_viaducts  scenes
# 5                         bus_or_tram_exterior  scenes
# 6                                 car_exterior  scenes
# 7                 cigarettes_or_street_smoking  scenes
# 8                                    city_park  scenes
# 9                                  city_square  scenes
# 10                        cloudy_weather_scene  scenes
# 11                           construction_site  scenes
# 12                                country_road  scenes
# 13          crowd_of_people_at_an_indoor_event  scenes
# 14               crowd_of_people_on_the_street  scenes
# 15                            factory_exterior  scenes
# 16                            factory_interior  scenes
# 17                          farmland_landscape  scenes
# 18           fountains_or_urban_water_features  scenes
# 19      graffiti_or_political_slogans_on_walls  scenes
# 20                     group_of_people_indoors  scenes
# 21                    group_of_people_outdoors  scenes
# 22             historic_buildings_or_tenements  scenes
# 23                    hot_air_balloon_exterior  scenes
# 24                          interior_of_a_flat  scenes
# 25                         lake_or_river_scene  scenes
# 26             modern_buildings_or_skyscrapers  scenes
# 27               monuments_or_urban_sculptures  scenes
# 28                       music_studio_interior  scenes
# 29  musical_instruments_or_street_performances  scenes
# SUBJECTS: 1204 rows | brak PL: 0
# SCENES:   56 rows | brak PL: 0
# SUBJECTS duplicate keys: 0
# SCENES duplicate keys:   0
# Empty DataFrame
# Columns: [key, en, pl]
# Index: []
# Empty DataFrame
# Columns: [key, en, pl]
# Index: []
# Wrote test files:
#  - /Users/olga/MetaLogic/data/_TEST_dictionary_subjects.normalized.csv
#  - /Users/olga/MetaLogic/data/_TEST_dictionary_scenes.normalized.csv

# %%
"""
Diagnostyka CSV: wykrycie separatora i podgląd problematycznej linii.
"""
from pathlib import Path
import csv

p = Path("/Users/olga/MetaLogic/data/dictionary_subjects.csv")

# 1) sniff separator
sample = p.read_text(encoding="utf-8", errors="replace")[:20000]
dialect = csv.Sniffer().sniff(sample, delimiters=[",",";","\t","|"])
print("Detected delimiter:", repr(dialect.delimiter))

# 2) pokaż linię wskazaną przez pandas (1-indexed; w błędzie: line 683)
bad_line_no = 683
lines = p.read_text(encoding="utf-8", errors="replace").splitlines()
print("Header:", lines[0])
print(f"Line {bad_line_no}:", lines[bad_line_no-1])
# Out:
# Detected delimiter: ';'
# Header: subject_en;subject_pl
# Line 683: measuring_stick;miarka (linijka, tyczka pomiarowa)

# %%
"""
Odporne wczytanie CSV: właściwy separator + python engine + pomijanie złych linii (do diagnozy).
Nic nie zapisuje.
"""
from pathlib import Path
import pandas as pd

p = Path("/Users/olga/MetaLogic/data/dictionary_subjects.csv")

# jeśli w Komórce 1 wyszło ';', wpisz sep=';'
df_raw = pd.read_csv(
    p,
    sep=";",              # <- zmień na wykryty delimiter: ',', ';', '\t', '|'
    engine="python",
    on_bad_lines="warn",  # pokaże ostrzeżenia i pominie linie do czasu naprawy
)

print("shape:", df_raw.shape)
print("columns:", df_raw.columns.tolist())
display(df_raw.head(10))
# Out:
# shape: (1204, 2)
# columns: ['subject_en', 'subject_pl']
#         subject_en             subject_pl
# 0      aerosol_can      puszka aerozolowa
# 1  air_conditioner           klimatyzator
# 2         airplane                samolot
# 3      alarm_clock                 budzik
# 4          alcohol                alkohol
# 5        alligator               aligator
# 6           almond                 migdał
# 7        ambulance                karetka
# 8        amplifier             wzmacniacz
# 9           anklet  bransoletka na kostkę
