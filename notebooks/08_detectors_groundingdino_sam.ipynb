# %% [markdown]
# ##### Tylko placeholder na przyszłość (GPU).
# Zaczniesz z nim pracować dopiero po migracji na GCP.

# %% [markdown]
# ### 0. Placeholder: konfiguracja detektorów cięższych (Grounding DINO, SAM+CLIP)

# %%
"""
Ten notatnik jest szkieletem pod przyszłe eksperymenty na GCP z GPU.

Cele:
- uruchomienie Grounding DINO z tym samym zbiorem testowym i promptami,
- eksperymentalne użycie SAM+CLIP do segmentacji i klasyfikacji obiektów.

Na Macu można go pozostawić pustym lub używać wyłącznie do notatek.
"""

# %% [markdown]
# ### 1. Importy i ścieżki (do wypełnienia po migracji na GCP)

# %%
# TODO: dodać importy i konfigurację środowiska GPU po przejściu na GCP.

# %% [markdown]
# ### 2. Szkic funkcji run_grounding_dino

# %%
def run_grounding_dino(file_names: list[str]) -> pd.DataFrame:
    """
    Szkic funkcji do uruchamiania Grounding DINO.

    file_names – lista nazw plików (bez ścieżek).
    Zwraca DataFrame z kolumnami DETECTIONS_COLUMNS (jak w innych notatnikach).

    Implementacja do uzupełnienia po skonfigurowaniu środowiska GPU.
    """
    raise NotImplementedError("Implementacja Grounding DINO wymaga środowiska GPU.")

# %% [markdown]
# ### 3. Szkic funkcji run_sam_clip

# %%
def run_sam_clip(file_names: list[str]) -> pd.DataFrame:
    """
    Szkic funkcji do uruchamiania SAM + CLIP.

    file_names – lista nazw plików (bez ścieżek).
    Zwraca DataFrame z kolumnami DETECTIONS_COLUMNS.

    Implementacja do uzupełnienia po skonfigurowaniu środowiska GPU.
    """
    raise NotImplementedError("Implementacja SAM+CLIP wymaga środowiska GPU.")
